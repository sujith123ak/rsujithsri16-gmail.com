# %%
import numpy as np

# Given data
data = [
    [5, 3],
    [10, 15],
    [15, 12],
    [24, 10],
    [30, 30],
    [85, 70],
    [71, 80],
    [60, 78],
    [70, 55],
    [80, 91]
]

# %%
# Create a NumPy array from the data
data_array = np.array(data)
print(data_array)
# Out:
# [[ 5  3]
#  [10 15]
#  [15 12]
#  [24 10]
#  [30 30]
#  [85 70]
#  [71 80]
#  [60 78]
#  [70 55]
#  [80 91]]

# %%
import matplotlib.pyplot as plt

# Generate scatter plot
plt.figure(figsize=(8, 6))

# %%
plt.scatter(data_array[:, 0], data_array[:, 1], color='blue')

# %%
plt.xlabel('X-axis')
# Out:
# Text(0.5, 0, 'X-axis')

# %%
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.title('Scatter Plot of the Data')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of the Data')

# %%
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# Perform hierarchical/agglomerative clustering
linked = linkage(data_array, method='ward')

# %%
# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram(linked,
           orientation='top',
           distance_sort='descending',
           show_leaf_counts=True)
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [10.0, 10.0, 25.0, 25.0],
#   [35.0, 35.0, 45.0, 45.0],
#   [17.5, 17.5, 40.0, 40.0],
#   [55.0, 55.0, 65.0, 65.0],
#   [60.0, 60.0, 75.0, 75.0],
#   [67.5, 67.5, 85.0, 85.0],
#   [76.25, 76.25, 95.0, 95.0],
#   [28.75, 28.75, 85.625, 85.625]],
#  'dcoord': [[0.0, 11.180339887498949, 11.180339887498949, 0.0],
#   [11.180339887498949, 21.73323108360405, 21.73323108360405, 0.0],
#   [0.0, 21.213203435596427, 21.213203435596427, 0.0],
#   [21.73323108360405,
#    33.64322616317684,
#    33.64322616317684,
#    21.213203435596427],
#   [0.0, 5.830951894845301, 5.830951894845301, 0.0],
#   [5.830951894845301, 13.880441875771343, 13.880441875771343, 0.0],
#   [13.880441875771343, 17.98147194568157, 17.98147194568157, 0.0],
#   [17.98147194568157, 32.796341259353916, 32.796341259353916, 0.0],
#   [33.64322616317684,
#    185.44001725625458,
#    185.44001725625458,
#    32.796341259353916]],
#  'ivl': ['7', '6', '9', '8', '5', '2', '1', '3', '0', '4'],
#  'leaves': [7, 6, 9, 8, 5, 2, 1, 3, 0, 4],
#  'color_list': ['C1', 'C1', 'C1', 'C1', 'C2', 'C2', 'C2', 'C2', 'C0'],
#  'leaves_color_list': ['C1',
#   'C1',
#   'C1',
#   'C1',
#   'C1',
#   'C2',
#   'C2',
#   'C2',
#   'C2',
#   'C2']}

# %%
plt.title('Dendrogram')
# Out:
# Text(0.5, 1.0, 'Dendrogram')

# %%
plt.show()
