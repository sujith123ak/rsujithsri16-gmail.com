# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Sample data for demonstration (replace this with your actual DataFrame)
data = {
    'wt': [2.62, 2.875, 2.32, 3.215, 3.44, 3.46, 3.57, 3.19, 3.15, 3.44, 3.44, 4.07, 3.73, 3.78, 3.845, 1.935, 2.14, 1.513, 3.17, 2.77, 3.57, 3.57, 4.07, 3.73, 3.78, 5.25, 5.424, 5.345, 5.714, 6.318, 6.165, 5.424]
}
df = pd.DataFrame(data)

# %%
# Plotting the histogram
plt.figure(figsize=(10, 6))

# %%
plt.hist(df['wt'], bins=30, color='blue', edgecolor='black')
# Out:
# (array([1., 0., 1., 1., 0., 1., 1., 1., 1., 0., 4., 0., 7., 2., 3., 2., 0.,
#         0., 0., 0., 0., 0., 0., 2., 2., 0., 1., 0., 0., 2.]),
#  array([1.513     , 1.67316667, 1.83333333, 1.9935    , 2.15366667,
#         2.31383333, 2.474     , 2.63416667, 2.79433333, 2.9545    ,
#         3.11466667, 3.27483333, 3.435     , 3.59516667, 3.75533333,
#         3.9155    , 4.07566667, 4.23583333, 4.396     , 4.55616667,
#         4.71633333, 4.8765    , 5.03666667, 5.19683333, 5.357     ,
#         5.51716667, 5.67733333, 5.8375    , 5.99766667, 6.15783333,
#         6.318     ]),
#  <BarContainer object of 30 artists>)

# %%
plt.xlabel('Weight of the Cars')
# Out:
# Text(0.5, 0, 'Weight of the Cars')

# %%
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.title('Histogram for the Weight Values')
# Out:
# Text(0.5, 1.0, 'Histogram for the Weight Values')

# %%
plt.grid(axis='y', alpha=0.75)

# %%
plt.show()
